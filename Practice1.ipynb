# %%
# Load everything 
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as mlt
import seaborn as sb 
import cufflinks as cfk

# %%
#Importing the dataset 
df=pd.read_csv('social_media_dopamine_productivity.csv')
df
# Out:
#     participant_id   data_source  synthetic_flag  age age_group  gender  \
# 0            P0001  synthetic_ai               1   16     13-17  Female
# 1            P0002  synthetic_ai               1   17     13-17    Male
# 2            P0003  synthetic_ai               1   15     13-17  Female
# 3            P0004  synthetic_ai               1   19     18-22    Male
# 4            P0005  synthetic_ai               1   18     18-22  Female
# ..             ...           ...             ...  ...       ...     ...
# 295          P0296  synthetic_ai               1   24     23-27  Female
# 296          P0297  synthetic_ai               1   35     28-35    Male
# 297          P0298  synthetic_ai               1   20     18-22  Female
# 298          P0299  synthetic_ai               1   46     36-49    Male
# 299          P0300  synthetic_ai               1   22     18-22    Male
#
#       race_ethnicity nationality country_of_residence education_level  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 66 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   participant_id                    300 non-null    str
#  1   data_source                       300 non-null    str
#  2   synthetic_flag                    300 non-null    int64
#  3   age                               300 non-null    int64
#  4   age_group                         300 non-null    str
#  5   gender                            300 non-null    str
#  6   race_ethnicity                    300 non-null    str
#  7   nationality                       300 non-null    str
#  8   country_of_residence              300 non-null    str
#  9   education_level                   300 non-null    str
#  10  employment_status                 300 non-null    str
#  11  occupation_category               300 non-null    str
# ...

# %%
#QUe-> Print its first 5 rows, the total number of rows and columns (shape), and the list of all column names.
df.head()
# Out:
#   participant_id   data_source  synthetic_flag  age age_group  gender  \
# 0          P0001  synthetic_ai               1   16     13-17  Female
# 1          P0002  synthetic_ai               1   17     13-17    Male
# 2          P0003  synthetic_ai               1   15     13-17  Female
# 3          P0004  synthetic_ai               1   19     18-22    Male
# 4          P0005  synthetic_ai               1   18     18-22  Female
#
#     race_ethnicity nationality country_of_residence education_level  ...  \
# 0      South Asian      Indian                India     High school  ...
# 1       East Asian     Chinese                China     High school  ...
# 2    Black/African    Nigerian              Nigeria     High school  ...
# 3  White/Caucasian    American                  USA     High school  ...
# 4  Hispanic/Latino     Mexican               Mexico     High school  ...
#
#   mood_dependency_on_sm withdrawal_attempt_count longest_detox_days  \
# ...

# %%
df.shape
# Out:
# (300, 66)

# %%
df.columns
# Out:
# Index(['participant_id', 'data_source', 'synthetic_flag', 'age', 'age_group',
#        'gender', 'race_ethnicity', 'nationality', 'country_of_residence',
#        'education_level', 'employment_status', 'occupation_category',
#        'relationship_status', 'avg_daily_sm_hours', 'years_on_social_media',
#        'primary_platform', 'secondary_platform', 'daily_check_frequency',
#        'first_check_of_day', 'late_night_scrolling', 'sm_during_work_study',
#        'sm_during_meals', 'notifications_always_on', 'scroll_without_purpose',
#        'doomscrolling_frequency', 'content_type_consumed',
#        'avg_daily_screen_time_hours', 'avg_sleep_hours', 'sleep_quality',
#        'exercise_frequency', 'avg_work_study_hours_per_day',
#        'dopamine_rush_feel_score', 'reward_seeking_behavior', 'fomo_score',
#        'comparison_to_others_score', 'validation_seeking_score',
#        'boredom_to_phone_reflex', 'inability_to_delay_gratification',
# ...

# %%
#Que-> Find the average (mean), minimum, and maximum values of avg_daily_sm_hours
average=df['avg_daily_sm_hours'].mean()
print(average)
minimum= df['avg_daily_sm_hours'].min()
print(minimum)
maximum=df['avg_daily_sm_hours'].max()
print(maximum)
# Out:
# 4.03
# 0.5
# 9.0

# %%
#QUe-> Find how many participants use each primary_platform
df['primary_platform'].value_counts()
# Out:
# primary_platform
# Instagram        95
# Facebook         89
# YouTube          50
# LinkedIn         26
# TikTok           21
# WeChat           12
# Twitter/X         5
# Douyin/TikTok     1
# Reddit            1
# Name: count, dtype: int64

# %%
#Que-> Filter and display all rows where avg_daily_sm_hours is greater than 6 hours and gender is 'Female'
df[(df['avg_daily_sm_hours']>6 )&(df['gender']=='Female')]
# Out:
#     participant_id   data_source  synthetic_flag  age age_group  gender  \
# 0            P0001  synthetic_ai               1   16     13-17  Female
# 2            P0003  synthetic_ai               1   15     13-17  Female
# 4            P0005  synthetic_ai               1   18     18-22  Female
# 8            P0009  synthetic_ai               1   22     18-22  Female
# 14           P0015  synthetic_ai               1   20     18-22  Female
# 18           P0019  synthetic_ai               1   16     13-17  Female
# 20           P0021  synthetic_ai               1   17     13-17  Female
# 22           P0023  synthetic_ai               1   19     18-22  Female
# 28           P0029  synthetic_ai               1   17     13-17  Female
# 32           P0033  synthetic_ai               1   22     18-22  Female
# 34           P0035  synthetic_ai               1   16     13-17  Female
# 40           P0041  synthetic_ai               1   19     18-22  Female
# ...

# %%
#Que-> Group the data by gender and calculate the average attention_span_minutes for each group
df.groupby('gender')['attention_span_minutes'].mean()
# Out:
# gender
# Female        26.331081
# Male          29.103448
# Non-binary    16.428571
# Name: attention_span_minutes, dtype: float64

# %%
#Que-> How would you create a new column representing non-work screen time , 
df['non-work-ScreenTime']=df['avg_daily_screen_time_hours']-df['avg_work_study_hours_per_day']
df[['avg_daily_screen_time_hours']['avg_work_study_hours_per_day']['non-work-Screentime']].head()
# Out:
# <>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# <>:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
# /var/folders/xv/hsz4y13j7jd2_cbvgdphpb9w0000gn/T/ipykernel_33474/883219689.py:3: SyntaxWarning: list indices must be integers or slices, not str; perhaps you missed a comma?
#   df[['avg_daily_screen_time_hours']['avg_work_study_hours_per_day']['non-work-Screentime']].head()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 #Que-> How would you create a new column representing non-work screen time ,
#       2 df['non-work-ScreenTime']=df['avg_daily_screen_time_hours']-df['avg_work_study_hours_per_day']
# ----> 3 df[['avg_daily_screen_time_hours']['avg_work_study_hours_per_day']['non-work-Screentime']].head()
#
# ...
